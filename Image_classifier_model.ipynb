# %%
import pandas as pd
import numpy as np
import random
import os
import cv2
import keras
import seaborn as sns
import random
import matplotlib.pyplot as plt
# %matplotlib inline
from keras_preprocessing.image import ImageDataGenerator
from keras_preprocessing import image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from sklearn.metrics import accuracy_score
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
#loading the saved train data
x_train = np.load('x_train.npy')
y_train = np.load('y_train.npy')

# %%
f = 4
skf = StratifiedKFold(f, shuffle = True, random_state= 42)

# %%
Score= 0
pred = []
fold = 0

for train, test in skf.split(x_train,y_train):
    
    fold+= 1
    print("Fold", fold)
    
    x1_train = x_train[train]
    y1_train = y_train[train]
    x1_test = x_train[test]
    y1_test = y_train[test]
    
    
    model = Sequential()
    model.add(Conv2D(64, (3,3),input_shape = (124,124,1)))
    model.add(Activation("relu"))
    model.add(Conv2D(64, (3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size = (2,2)))

    model.add(Conv2D(128, (3,3)))
    model.add(Activation("relu"))
    model.add(Conv2D(128, (3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size = (2,2)))

    model.add(Conv2D(256, (3,3)))
    model.add(Activation("relu"))
    model.add(Conv2D(256, (3,3)))
    model.add(Activation("relu"))
    model.add(Conv2D(256, (3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size = (2,2)))

    model.add(Conv2D(512, (3,3)))
    model.add(Activation("relu"))
    model.add(Conv2D(512, (3,3)))
    model.add(Activation("relu"))
    model.add(Conv2D(512, (3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size = (2,2)))

    model.add(Flatten())
    model.add(Dense(4096))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.5))

    model.add(Dense(4096))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.5))

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile('adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
    model.fit(x1_train, y1_train, validation_data = (x1_test,y1_test), epochs = 10, batch_size = 42)
    
    p = model.predict_classes(x1_test, batch_size = 30)
    score = accuracy_score(y1_test, p)
    print("Fold accuracy: ", score)

    Score += score


print("Final accuracy", Score/f)
# Out:
# Fold 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 42935 samples, validate on 14316 samples
# Epoch 1/10
# 42935/42935 [==============================] - 91s 2ms/sample - loss: 2.2080 - acc: 0.2649 - val_loss: 2.4378 - val_acc: 0.1404
# Epoch 2/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 1.5712 - acc: 0.4379 - val_loss: 1.5513 - val_acc: 0.4084
# Epoch 3/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 1.0631 - acc: 0.6429 - val_loss: 0.8708 - val_acc: 0.7085
# Epoch 4/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.6206 - acc: 0.8095 - val_loss: 0.4822 - val_acc: 0.8420
# Epoch 5/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.3798 - acc: 0.8875 - val_loss: 0.5221 - val_acc: 0.8347
# Epoch 6/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.2982 - acc: 0.9152 - val_loss: 0.1102 - val_acc: 0.9666
# Epoch 7/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.1911 - acc: 0.9436 - val_loss: 0.1058 - val_acc: 0.9656
# Epoch 8/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.2701 - acc: 0.9297 - val_loss: 0.2286 - val_acc: 0.9322
# Epoch 9/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.1466 - acc: 0.9584 - val_loss: 0.0998 - val_acc: 0.9725
# Epoch 10/10
# 42935/42935 [==============================] - 86s 2ms/sample - loss: 0.0836 - acc: 0.9743 - val_loss: 0.1170 - val_acc: 0.9640
# Fold accuracy:  0.9640262643196423
# Fold 2
# Train on 42937 samples, validate on 14314 samples
# Epoch 1/10
# 42937/42937 [==============================] - 87s 2ms/sample - loss: 2.1859 - acc: 0.2659 - val_loss: 1.8737 - val_acc: 0.3390
# Epoch 2/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 1.4707 - acc: 0.4769 - val_loss: 1.1547 - val_acc: 0.6042
# Epoch 3/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 0.8368 - acc: 0.7232 - val_loss: 0.7107 - val_acc: 0.7708
# Epoch 4/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 0.5696 - acc: 0.8268 - val_loss: 1.1033 - val_acc: 0.6779
# Epoch 5/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 0.3908 - acc: 0.8866 - val_loss: 0.2874 - val_acc: 0.9059
# Epoch 6/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 0.2700 - acc: 0.9221 - val_loss: 0.1811 - val_acc: 0.9425
# Epoch 7/10
# 42937/42937 [==============================] - 86s 2ms/sample - loss: 0.2265 - acc: 0.9354 - val_loss: 0.2499 - val_acc: 0.9325
# Epoch 8/10
# 42937/42937 [==============================] - 87s 2ms/sample - loss: 0.2528 - acc: 0.9335 - val_loss: 0.1522 - val_acc: 0.9526
# Epoch 9/10
# 42937/42937 [==============================] - 87s 2ms/sample - loss: 0.1008 - acc: 0.9698 - val_loss: 0.1137 - val_acc: 0.9655
# Epoch 10/10
# 42937/42937 [==============================] - 87s 2ms/sample - loss: 0.1120 - acc: 0.9675 - val_loss: 0.0715 - val_acc: 0.9779
# Fold accuracy:  0.977853849378231
# Fold 3
# Train on 42940 samples, validate on 14311 samples
# Epoch 1/10
# 42940/42940 [==============================] - 87s 2ms/sample - loss: 2.2474 - acc: 0.2576 - val_loss: 2.0801 - val_acc: 0.2049
# Epoch 2/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 1.4788 - acc: 0.4738 - val_loss: 1.3778 - val_acc: 0.5114
# Epoch 3/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 0.8417 - acc: 0.7223 - val_loss: 0.5137 - val_acc: 0.8304
# Epoch 4/10
# 42940/42940 [==============================] - 87s 2ms/sample - loss: 0.5446 - acc: 0.8400 - val_loss: 0.2587 - val_acc: 0.9198
# Epoch 5/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 0.3678 - acc: 0.8943 - val_loss: 0.2435 - val_acc: 0.9285
# Epoch 6/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 0.2653 - acc: 0.9234 - val_loss: 0.2103 - val_acc: 0.9434
# Epoch 7/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 0.2698 - acc: 0.9258 - val_loss: 0.1464 - val_acc: 0.9593
# Epoch 8/10
# 42940/42940 [==============================] - 86s 2ms/sample - loss: 0.1309 - acc: 0.9609 - val_loss: 0.2125 - val_acc: 0.9424
# Epoch 9/10
# 42940/42940 [==============================] - 87s 2ms/sample - loss: 0.1703 - acc: 0.9537 - val_loss: 0.0907 - val_acc: 0.9741
# Epoch 10/10
# 42940/42940 [==============================] - 87s 2ms/sample - loss: 0.1060 - acc: 0.9684 - val_loss: 0.1511 - val_acc: 0.9588
# Fold accuracy:  0.958842848158759
# Fold 4
# Train on 42941 samples, validate on 14310 samples
# Epoch 1/10
# 42941/42941 [==============================] - 88s 2ms/sample - loss: 2.2729 - acc: 0.2279 - val_loss: 3.9340 - val_acc: 0.1885
# Epoch 2/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 1.6626 - acc: 0.4050 - val_loss: 1.3070 - val_acc: 0.5225
# Epoch 3/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 1.0142 - acc: 0.6657 - val_loss: 0.7045 - val_acc: 0.7675
# Epoch 4/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.6622 - acc: 0.8020 - val_loss: 0.5092 - val_acc: 0.8270
# Epoch 5/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.4390 - acc: 0.8689 - val_loss: 0.4569 - val_acc: 0.8724
# Epoch 6/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.3509 - acc: 0.9018 - val_loss: 0.1918 - val_acc: 0.9433
# Epoch 7/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.2364 - acc: 0.9310 - val_loss: 0.1243 - val_acc: 0.9581
# Epoch 8/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.3389 - acc: 0.9123 - val_loss: 0.1695 - val_acc: 0.9491
# Epoch 9/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.1624 - acc: 0.9533 - val_loss: 0.1279 - val_acc: 0.9583
# Epoch 10/10
# 42941/42941 [==============================] - 86s 2ms/sample - loss: 0.1244 - acc: 0.9636 - val_loss: 0.1450 - val_acc: 0.9568
# Fold accuracy:  0.9568134171907757
# Final accuracy 0.964384094761852
